# %% [markdown]
# ## Figure 7 - CP input-output chord diagram

# %% [markdown]
# Generate summary chord diagram based on connectivity patterns from cortical and subcortical structures to CP and CP outputs to downstream structures
#
# Uses holoviews and bokeh to generate chord diagram, which is then saved as a static image.

# %%
import holoviews as hv
import numpy as np
import pandas as pd
from bokeh.io import export_svgs
from matplotlib.colors import ListedColormap

hv.extension('bokeh')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
path = '../data/'

attrs = pd.read_csv(path+'Fig7b_attrs_chord.csv')
dataset = pd.read_csv(path+'Fig7b_summary_chord.csv')

print(attrs)
print(dataset)
# Out:
#         structure  struct_id    color
# 0      Prefrontal          1  #ff0000
# 1          Medial          2  #5252a9
# 2         Lateral          3  #ffcc00
# 3    Sensorimotor          4  #ff6600
# 4          Visual          5  #007dff
# 5        Auditory          6  #7C429B
# 6            CPdm          7  #98d5f9
# 7            CPvm          8  #98d5f9
# 8            CPiv          9  #98d5f9
# 9             CPl         10  #98d5f9
# 10            CPp         11  #98d5f9
# 11            PFd         14  #ff7081
# 12        PFal/pl         15  #ff7081
# 13          PFm/c         16  #ff7081
# 14           PFvm         17  #ff7081
# 15  bidirectional         18  #000000
#           Source        Target  strength  connection_type
# 0            PFd      Auditory         1                2
# 1           PFvm       Lateral         1                2
# 2            PFd        Medial         1                2
# 3   Sensorimotor       PFal/pl         3                2
# 4       Auditory           PFd         1                2
# 5         Medial           PFd         2                2
# 6         Visual           PFd         1                2
# 7     Prefrontal         PFm/c         2                2
# 8        Lateral          PFvm         1                2
# 9          PFm/c    Prefrontal         2                2
# 10       PFal/pl  Sensorimotor         3                2
# 11           PFd        Visual         1                2
# 12        Medial          CPdm         2                1
# 13           PFd          CPdm         2                1
# 14        Visual          CPdm         1                1
# 15       Lateral          CPiv         1                1
# 16          PFvm          CPiv         1                1
# 17       PFal/pl           CPl         3                1
# 18  Sensorimotor           CPl         3                1
# 19      Auditory           CPp         2                1
# 20           PFd           CPp         1                1
# 21         PFm/c          CPvm         2                1
# 22    Prefrontal          CPvm         1                1

# %%
source = dataset['Source'].to_numpy()
sink = dataset['Target'].to_numpy()

# %% [markdown]
# ### Check to make sure attributes are represented in dataset

# %%
dataset_source = np.unique(source)
dataset_sink = np.unique(sink)
attr_region = np.unique(attrs['structure'])

np.setdiff1d(dataset_source,attr_region)
# Out:
# array([], dtype=object)

# %%
np.setdiff1d(dataset_sink,attr_region)
# Out:
# array([], dtype=object)

# %% [markdown]
# Some data are grouped by their parent level and some have subdivisions (eg. GPe vs. GPe-d, GPe-m vs. GPe-dm, vm...)

# %% [markdown]
# #### Convert acronyms to indices for chord diagram

# %%
dataset_ids = dataset.copy()

source_ids = np.empty_like(source)
sink_ids = np.empty_like(sink)

for idx,region in enumerate(source):
    
    source_id = attrs.loc[attrs['structure']==region]['struct_id'].to_numpy()
    sink_id = attrs.loc[attrs['structure']==sink[idx]]['struct_id'].to_numpy()
    
    source_ids[idx] = source_id[0]
    sink_ids[idx] = sink_id[0]
    
dataset_ids['Source'] = source_ids
dataset_ids['Target'] = sink_ids
dataset_ids['strength'] *= 5 # Multiply by five to make chord ribbons thicker

# %%
edge_col = []

for idx,item in enumerate(dataset_ids['connection_type']):
    
    if item < 2:
        edge_col.append(dataset_ids.iloc[idx]['Source'])
    else:
        edge_col.append(18)
            
dataset_ids['connection_type'] = edge_col

dataset_ids
# Out:
#    Source Target  strength  connection_type
# 0      14      6         5               18
# 1      17      3         5               18
# 2      14      2         5               18
# 3       4     15        15               18
# 4       6     14         5               18
# 5       2     14        10               18
# 6       5     14         5               18
# 7       1     16        10               18
# 8       3     17         5               18
# 9      16      1        10               18
# 10     15      4        15               18
# 11     14      5         5               18
# 12      2      7        10                2
# 13     14      7        10               14
# 14      5      7         5                5
# 15      3      9         5                3
# 16     17      9         5               17
# 17     15     10        15               15
# 18      4     10        15                4
# 19      6     11        10                6
# 20     14     11         5               14
# 21     16      8        10               16
# 22      1      8         5                1

# %% [markdown]
# ### Set up chord diagram parameters

# %%
nodes = hv.Dataset(attrs,'struct_id')
nodes.data.head()
# Out:
#       structure  struct_id    color
# 0    Prefrontal          1  #ff0000
# 1        Medial          2  #5252a9
# 2       Lateral          3  #ffcc00
# 3  Sensorimotor          4  #ff6600
# 4        Visual          5  #007dff

# %%
chord = hv.Chord((dataset_ids,nodes))

# %%
struct_id = attrs['struct_id'].to_numpy()
color = attrs['color'].to_list()

brain_cmap = ListedColormap(color)

# %%
chord.opts(
    hv.opts.Chord(cmap = brain_cmap, edge_cmap = brain_cmap, edge_color = hv.dim('Source').str(),
               labels='structure', node_color = hv.dim('struct_id').str())

)
chord
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('angle', 15), ('text', 16), ('x', 15), ('y', 15)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('angle', 15), ('text', 16), ('x', 15), ('y', 15)
# :Chord   [Source,Target]   (strength,connection_type)

# %%
plot_fmt = hv.renderer('bokeh').get_plot(chord).state
plot_fmt.output_backend = 'svg'
export_svgs(plot_fmt,filename='../figures/ExtendedData19_CTX_PF_CP_summary.svg')
# Out:
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('angle', 15), ('text', 16), ('x', 15), ('y', 15)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('angle', 15), ('text', 16), ('x', 15), ('y', 15)
# ['../figures/ExtendedData19_CTX_PF_CP_summary.svg']
