# %% [markdown]
# ## Figure 7 - CP input-output chord diagram

# %% [markdown]
# Generate summary chord diagram based on connectivity patterns from cortical and subcortical structures to CP and CP outputs to downstream structures
#
# Uses holoviews and bokeh to generate chord diagram, which is then saved as a static image.

# %%
import holoviews as hv
import numpy as np
import pandas as pd
from bokeh.io import export_svgs
from matplotlib.colors import ListedColormap

hv.extension('bokeh')
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
path = '../data/'

attrs = pd.read_csv(path+'Fig7b_attrs_chord.csv')
dataset = pd.read_csv(path+'Fig7b_summary_chord.csv')

print(attrs)
print(dataset)
# Out:
#        structure  struct_id    color
# 0     Prefrontal          1  #ff0000
# 1         Medial          2  #5252a9
# 2        Lateral          3  #ffcc00
# 3   Sensorimotor          4  #ff6600
# 4         Visual          5  #007dff
# 5       Auditory          6  #7C429B
# 6           CPdm          7  #98d5f9
# 7           CPvm          8  #98d5f9
# 8           CPiv          9  #98d5f9
# 9            CPl         10  #98d5f9
# 10           CPp         11  #98d5f9
# 11           PFd         14  #ff7081
# 12       PFal/pl         15  #ff7081
# 13         PFm/c         16  #ff7081
# 14          PFvm         17  #ff7081
#           Source        Target  strength
# 0       Auditory           CPp         2
# 1       Auditory           PFd         1
# 2        Lateral          CPiv         1
# 3        Lateral          PFvm         1
# 4         Medial          CPdm         2
# 5         Medial           PFd         2
# 6        PFal/pl           CPl         3
# 7        PFal/pl  Sensorimotor         3
# 8            PFd      Auditory         1
# 9            PFd          CPdm         2
# 10           PFd           CPp         1
# 11           PFd        Medial         1
# 12           PFd        Visual         1
# 13         PFm/c          CPvm         2
# 14         PFm/c    Prefrontal         2
# 15          PFvm          CPiv         1
# 16          PFvm       Lateral         1
# 17    Prefrontal          CPvm         1
# 18    Prefrontal         PFm/c         2
# 19  Sensorimotor           CPl         3
# 20  Sensorimotor       PFal/pl         3
# 21        Visual          CPdm         1
# 22        Visual           PFd         1

# %%
source = dataset['Source'].to_numpy()
sink = dataset['Target'].to_numpy()

# %% [markdown]
# ### Check to make sure attributes are represented in dataset

# %%
dataset_source = np.unique(source)
dataset_sink = np.unique(sink)
attr_region = np.unique(attrs['structure'])

np.setdiff1d(dataset_source,attr_region)
# Out:
# array([], dtype=object)

# %%
np.setdiff1d(dataset_sink,attr_region)
# Out:
# array([], dtype=object)

# %% [markdown]
# Some data are grouped by their parent level and some have subdivisions (eg. GPe vs. GPe-d, GPe-m vs. GPe-dm, vm...)

# %% [markdown]
# #### Convert acronyms to indices for chord diagram

# %%
dataset_ids = dataset.copy()

source_ids = np.empty_like(source)
sink_ids = np.empty_like(sink)

for idx,region in enumerate(source):
    
    source_id = attrs.loc[attrs['structure']==region]['struct_id'].to_numpy()
    sink_id = attrs.loc[attrs['structure']==sink[idx]]['struct_id'].to_numpy()
    
    source_ids[idx] = source_id[0]
    sink_ids[idx] = sink_id[0]
    
dataset_ids['Source'] = source_ids
dataset_ids['Target'] = sink_ids
dataset_ids['strength'] *= 5

dataset_ids
# Out:
#    Source Target  strength
# 0       6     11        10
# 1       6     14         5
# 2       3      9         5
# 3       3     17         5
# 4       2      7        10
# 5       2     14        10
# 6      15     10        15
# 7      15      4        15
# 8      14      6         5
# 9      14      7        10
# 10     14     11         5
# 11     14      2         5
# 12     14      5         5
# 13     16      8        10
# 14     16      1        10
# 15     17      9         5
# 16     17      3         5
# 17      1      8         5
# 18      1     16        10
# 19      4     10        15
# 20      4     15        15
# 21      5      7         5
# 22      5     14         5

# %% [markdown]
# ### Set up chord diagram parameters

# %%
nodes = hv.Dataset(attrs,'struct_id')
nodes.data.head()
# Out:
#       structure  struct_id    color
# 0    Prefrontal          1  #ff0000
# 1        Medial          2  #5252a9
# 2       Lateral          3  #ffcc00
# 3  Sensorimotor          4  #ff6600
# 4        Visual          5  #007dff

# %%
chord = hv.Chord((dataset_ids,nodes))

# %%
struct_id = attrs['struct_id'].to_numpy()
color = attrs['color'].to_list()

brain_cmap = ListedColormap(color)

# %%
chord.opts(
    hv.opts.Chord(cmap = brain_cmap, edge_cmap = brain_cmap, edge_color = hv.dim('Source').str(), edge_cap = '>',
               labels='structure', node_color = hv.dim('struct_id').str())

)
chord
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
#       1 chord.opts(
# ----> 2     hv.opts.Chord(cmap = brain_cmap, edge_cmap = brain_cmap, edge_color = hv.dim('Source').str(), edge_cap = '>',
#       3                labels='structure', node_color = hv.dim('struct_id').str())
#       4
#       5 )
#       6 chord
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\holoviews\util\__init__.py:483, in opts._create_builder.<locals>.builder(cls, spec, **kws)
#     480         reraise = True
#     482     if reraise:
# --> 483         raise ValueError(prefix + msg)
#     485 return Options(spec, **kws)
#
# ValueError: In opts.Chord(...), unexpected option 'edge_cap' for Chord type across all extensions. Similar options for current extension ('bokeh') are: ['edge_alpha', 'edge_cmap', 'edge_line_cap'].

# %%
plot_fmt = hv.renderer('bokeh').get_plot(chord).state
plot_fmt.output_backend = 'svg'
export_svgs(plot_fmt,filename='../figures/ExtendedData19_CTX_PF_CP_summary.svg')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       1 plot_fmt = hv.renderer('bokeh').get_plot(chord).state
#       2 plot_fmt.output_backend = 'svg'
# ----> 3 export_svgs(plot_fmt,filename='../figures/ExtendedData19_CTX_PF_CP_summary.svg')
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\bokeh\io\export.py:194, in export_svgs(obj, filename, width, height, webdriver, timeout)
#     160 def export_svgs(obj: LayoutDOM | Document, *, filename: str | None = None, width: int | None = None,
#     161         height: int | None = None, webdriver: WebDriver | None = None, timeout: int = 5) -> List[str]:
#     162     ''' Export the SVG-enabled plots within a layout. Each plot will result
#     163     in a distinct SVG file.
#     164
#    (...)
#     192
#     193     '''
# --> 194     svgs = get_svgs(obj, width=width, height=height, driver=webdriver, timeout=timeout)
#     196     if len(svgs) == 0:
#     197         log.warning("No SVG Plots were found.")
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\bokeh\io\export.py:273, in get_svgs(obj, driver, timeout, resources, width, height)
#     270 with open(tmp.path, mode="w", encoding="utf-8") as file:
#     271     file.write(html)
# --> 273 web_driver = driver if driver is not None else webdriver_control.get()
#     274 web_driver.get(f"file://{tmp.path}")
#     275 wait_until_render_complete(web_driver, timeout)
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\bokeh\io\webdriver.py:153, in _WebdriverState.get(self)
#     151 if not self.reuse or self.current is None:
#     152     self.reset()
# --> 153     self.current = self.create()
#     154 return self.current
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\bokeh\io\webdriver.py:157, in _WebdriverState.create(self, kind)
#     156 def create(self, kind: DriverKind | None = None) -> WebDriver:
# --> 157     driver = self._create(kind)
#     158     self._drivers.add(driver)
#     159     return driver
#
# File ~\Anaconda3\envs\plotting\lib\site-packages\bokeh\io\webdriver.py:175, in _WebdriverState._create(self, kind)
#     172         self.kind = "firefox"
#     173         return driver
# --> 175     raise RuntimeError("Neither firefox and geckodriver nor a variant of chromium browser and " \
#     176                        "chromedriver are available on system PATH. You can install the former " \
#     177                        "with 'conda install -c conda-forge firefox geckodriver'.")
#     178 elif driver_kind == "chromium":
#     179     return create_chromium_webdriver()
#
# RuntimeError: Neither firefox and geckodriver nor a variant of chromium browser and chromedriver are available on system PATH. You can install the former with 'conda install -c conda-forge firefox geckodriver'.
